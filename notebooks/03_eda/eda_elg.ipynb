# %% [markdown]
# # EDA — ELG
#
# Analise exploratoria de espectros de ELG.

# %% [markdown]
# ## 1. Setup

# %%
import sys
from pathlib import Path

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = NOTEBOOK_DIR
while not (PROJECT_ROOT / "config.py").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

from config import paths_for, RESULTS_DIR as PROJECT_RESULTS, MODELS_DIR, print_info

OBJECT_TYPE = "ELG"
print_info()

paths = paths_for(OBJECT_TYPE)
HDF5_PATH = paths["spectra_h5"].with_name(f"{OBJECT_TYPE}spectra_padded.h5")
print(f"\nObjeto: {OBJECT_TYPE}")
print(f"HDF5:   {HDF5_PATH}")

# %%
import h5py, numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
with h5py.File(HDF5_PATH, "r") as f:
    X_spec = f["ml_dataset/X_spec"][:]
    y      = f["ml_dataset/y"][:]
    n_pts  = X_spec.shape[1]
print(f"N = {len(y):,}, L = {n_pts}")

# %% [markdown]
# ## 2. Espectros tipicos de ELG
#
# Linhas caracteristicas:
# - ELG: [O II] 3727, [O III] 5007, H-alpha 6563
# - LRG: break 4000A, Ca II H&K, Mg I/II
# - QSO: Ly-alpha 1216, C IV 1549, Mg II 2798

# %%
# TODO: grid de espectros tipicos (z baixo/medio/alto, S/N alto/baixo)

# %% [markdown]
# ## 3. Stack mediano por bin de z

# %%
# TODO: empilhar e mostrar evolucao das linhas
