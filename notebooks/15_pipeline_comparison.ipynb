# %% [markdown]
# # Comparacao com Pipeline SDSS
#
# Concordancia ML vs idlspec2d/redrock. Onde discordam? ZWARNING != 0 recuperado?

# %% [markdown]
# ## 1. Setup

# %%
import sys
from pathlib import Path
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = NOTEBOOK_DIR
while not (PROJECT_ROOT / "config.py").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

from config import RESULTS_DIR as PROJECT_RESULTS, MODELS_DIR, OBJECT_TYPES, paths_for

# %% [markdown]
# ## 2. (TODO) Implementacao

# %%
# TODO
